# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline #tensorflow
# Out:
# UsageError: unrecognized arguments: #tensorflow

# %%
(train_image,train_label),(test_image,test_label) = tf.keras.datasets.fashion_mnist.load_data()

# %%
train_label_onehot = tf.keras.utils.to_categorical(train_label)
test_label_onehot = tf.keras.utils.to_categorical(test_label)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))#扁平化图像，转化为向量处理
model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))#用于减少过拟合
model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10,activation = 'softmax'))#将结果转化为概率分布

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc']
             )

# %%
history = model.fit(train_image,train_label_onehot,
                    epochs=5,
                    validation_data=(test_image,test_label_onehot))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 3.6113 - acc: 0.1297 - val_loss: 2.2419 - val_acc: 0.1370
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.2381 - acc: 0.1390 - val_loss: 2.1983 - val_acc: 0.1440
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.2148 - acc: 0.1441 - val_loss: 2.1423 - val_acc: 0.1633
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.1860 - acc: 0.1518 - val_loss: 2.1060 - val_acc: 0.1855
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.1182 - acc: 0.1848 - val_loss: 1.8031 - val_acc: 0.2867

# %%
plt.plot(history.epoch,history.history.get('loss') ,label='loss')
plt.plot(history.epoch,history.history.get('val_loss') ,label='val_loss')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.plot(history.epoch,history.history.get('acc') ,label='acc')
plt.plot(history.epoch,history.history.get('val_acc') ,label='val_acc')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))#扁平化图像，转化为向量处理
model.add(tf.keras.layers.Dense(32,activation = 'relu'))
model.add(tf.keras.layers.Dense(10,activation = 'softmax'))#将结果转化为概率分布

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc']
             )

# %%
history = model.fit(train_image,train_label_onehot,
                    epochs=5,
                    validation_data=(test_image,test_label_onehot))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 853us/step - loss: 2.5807 - acc: 0.3061 - val_loss: 1.6418 - val_acc: 0.3303
# Epoch 2/5
# 1875/1875 [==============================] - 2s 801us/step - loss: 1.3263 - acc: 0.4528 - val_loss: 1.1586 - val_acc: 0.5713
# Epoch 3/5
# 1875/1875 [==============================] - 2s 803us/step - loss: 1.0165 - acc: 0.5824 - val_loss: 0.9764 - val_acc: 0.6052
# Epoch 4/5
# 1875/1875 [==============================] - 2s 801us/step - loss: 0.9060 - acc: 0.6254 - val_loss: 0.9091 - val_acc: 0.6274
# Epoch 5/5
# 1875/1875 [==============================] - 2s 806us/step - loss: 0.8790 - acc: 0.6313 - val_loss: 0.8874 - val_acc: 0.6195

# %%
plt.plot(history.epoch,history.history.get('loss') ,label='loss')
plt.plot(history.epoch,history.history.get('val_loss') ,label='val_loss')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.plot(history.epoch,history.history.get('acc') ,label='acc')
plt.plot(history.epoch,history.history.get('val_acc') ,label='val_acc')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>
